# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
 #df.drop('BMI', axis=1, inplace=True)
df = df.drop('BMI', axis=1)

# %%
# df.drop('smoking', axis=1, inplace=True)
df = df.drop('Smoking', axis=1)

# %%
df.isnull().sum()
# Out:
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# Sex                              0
# Pregnancy                        0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
def fillnaIntMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['Sex','Age','Level_of_Stress','Pregnancy','Physical_activity','Chronic_kidney_disease']
fillnaIntMode(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Blood_Pressure_Abnormality     2000 non-null   int64
#  1   Level_of_Hemoglobin            2000 non-null   float64
#  2   Genetic_Pedigree_Coefficient   2000 non-null   float64
#  3   Age                            2000 non-null   int64
#  4   Sex                            2000 non-null   int64
#  5   Pregnancy                      2000 non-null   int64
#  6   Physical_activity              2000 non-null   int64
#  7   salt_content_in_the_diet       2000 non-null   int64
#  8   alcohol_consumption_per_day    2000 non-null   int64
#  9   Level_of_Stress                2000 non-null   int64
#  10  Chronic_kidney_disease         2000 non-null   int64
#  11  Adrenal_and_thyroid_disorders  2000 non-null   int64
# dtypes: float64(2), int64(10)
# ...

# %%
df['Sex'] = df['Sex'].astype('int64')
# df['price'].astype('int64', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Blood_Pressure_Abnormality     2000 non-null   int64
#  1   Level_of_Hemoglobin            2000 non-null   float64
#  2   Genetic_Pedigree_Coefficient   2000 non-null   float64
#  3   Age                            2000 non-null   int64
#  4   Sex                            2000 non-null   int64
#  5   Pregnancy                      2000 non-null   int64
#  6   Physical_activity              2000 non-null   int64
#  7   salt_content_in_the_diet       2000 non-null   int64
#  8   alcohol_consumption_per_day    2000 non-null   int64
#  9   Level_of_Stress                2000 non-null   int64
#  10  Chronic_kidney_disease         2000 non-null   int64
#  11  Adrenal_and_thyroid_disorders  2000 non-null   int64
# dtypes: float64(2), int64(10)
# ...

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.DataFrame({'Sex':df['Sex'].unique()})
data_LE = LabelEncoder()
data_LE.fit(np.ravel(data))    # data_LE.fit(data)
df['Sex'] = data_LE.transform(df['Sex'])

# %%
def convertObjToInt(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_LE = LabelEncoder()
        data_LE.fit(np.ravel(data))    # data_LE.fit(data)
        df[i] = data_LE.transform(df[i])
        
columns = ['Sex', 'Age', 'Pregnancy']
convertObjToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Blood_Pressure_Abnormality     2000 non-null   int64
#  1   Level_of_Hemoglobin            2000 non-null   float64
#  2   Genetic_Pedigree_Coefficient   2000 non-null   float64
#  3   Age                            2000 non-null   int64
#  4   Sex                            2000 non-null   int64
#  5   Pregnancy                      2000 non-null   int64
#  6   Physical_activity              2000 non-null   int64
#  7   salt_content_in_the_diet       2000 non-null   int64
#  8   alcohol_consumption_per_day    2000 non-null   int64
#  9   Level_of_Stress                2000 non-null   int64
#  10  Chronic_kidney_disease         2000 non-null   int64
#  11  Adrenal_and_thyroid_disorders  2000 non-null   int64
# dtypes: float64(2), int64(10)
# ...

# %%
df.to_csv('cleaned_data.csv', index=False, header=True)
